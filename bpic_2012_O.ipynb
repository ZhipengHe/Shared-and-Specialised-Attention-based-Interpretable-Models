# %% [markdown]
# ### **BPIC 2012 - No milestone**

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from data.processor import *
from data.args import *

from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Define the experiment parameters

# %%
milestone = 'All' #'A_PREACCEPTED' # 'W_Nabellen offertes', 'All'
subset = "O"
experiment =  'OHE'#'Standard'#'OHE', 'No_loops'
n_size = 5
max_size = 1000 #  3, 5, 10, 15, 20, 30, 50, 95
min_size = 0  # 0, 3, 5, 10, 15, 20, 30, 50

# %% [markdown]
# ### Setting up the key parameters

# %%
# # For local environment only

MY_WORKSPACE_DIR = os.path.join(os.getcwd(),'BPIC12')
MILESTONE_DIR = os.path.join(os.path.join(MY_WORKSPACE_DIR, milestone),experiment)

# %%
args = get_parameters('bpic12', MILESTONE_DIR, MY_WORKSPACE_DIR, milestone, experiment,n_size)
args
# Out:
# {'folder': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\output_files',
#  'lstm_act': None,
#  'dense_act': None,
#  'optim': 'Adam',
#  'norm_method': 'lognorm',
#  'model_type': 'shared_cat',
#  'l_size': 50,
#  'n_size': 5,
#  'file_name': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\BPIC_2012_Prefixes.csv',
#  'file_name_all': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\BPIC_2012_Prefixes_all.csv',
#  'processed_file_name': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\BPIC_2012_Processed.csv',
#  'processed_training_vec': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\vec_training.p',
#  'processed_test_vec': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\vec_test.p',
#  'processed_val_vec': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\vec_val.p',
#  'weights': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\weights.p',
#  'indexes': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\indexes.p',
#  'pre_index': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\pre_index.p',
#  'args': 'c:\\Users\\mithr\\Documents\\GitHub\\KBS-SI-Paper\\BPIC12\\All\\OHE\\args.p',
#  'milestone': 'All',
#  'experiment': 'OHE',
#  'prefix_length': 'fixed',
#  'log_name': 'bpic12'}

# %%
#This code will be specific for all next activity prediction only, since we save the models and vectors by prefix length groups
# if milestone == 'All':
#   args['indexes'] = MILESTONE_DIR+'indexes_'+str(max_size)+'.p'
#   args['pre_index'] = MILESTONE_DIR+'pre_index_'+str(max_size)+'.p'
#   args['processed_test_vec'] = MILESTONE_DIR+'vec_test_'+str(max_size)+'.p'
#   args['processed_training_vec'] = MILESTONE_DIR+'vec_training_'+str(max_size)+'.p'
#   args['weights'] = MILESTONE_DIR+'weights_'+str(max_size)+'.p'

args['file_name_A_ex'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_A_ex.csv" )
args['file_name_O_ex'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_O_ex.csv" )
args['file_name_A_all'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_A_all.csv" )
args['file_name_O_all'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_O_all.csv" )
args['file_name_W_all'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_W_all.csv" )

# %% [markdown]
# ###Data Preprocessing

# %%
log_df = pd.read_csv(args['file_name_O_all'])
log_df = log_df.reset_index(drop=True)


log_df.head()
# Out:
#   prefix_id  caseid        task             role                end_timestamp  \
# 0  173796_1  173796  O_SELECTED  role_     11001  2011-10-03 19:15:53.5370000
# 1  173835_1  173835  O_SELECTED  role_     11180  2011-10-03 18:35:59.2790000
# 2  173871_4  173871  O_SELECTED  role_     10909  2011-10-05 03:40:46.5260000
# 3  173871_4  173871   O_CREATED  role_     10909  2011-10-05 03:40:47.7410000
# 4  173871_4  173871      O_SENT  role_     10909  2011-10-05 03:40:47.8250000
#
#                    trace_start  timelapsed next_activity    milestone  \
# 0  2011-10-03 19:15:53.5370000           0     O_CREATED   O_SELECTED
# 1  2011-10-03 18:35:59.2790000           0     O_CREATED   O_SELECTED
# 2  2011-10-05 03:40:46.5260000           0    O_DECLINED  O_SENT_BACK
# 3  2011-10-05 03:40:46.5260000           0    O_DECLINED  O_SENT_BACK
# 4  2011-10-05 03:40:46.5260000           0    O_DECLINED  O_SENT_BACK
#
#    milestone_id  task_index  prefix_length
# 0             1           1              1
# 1             1           1              1
# 2             4           1              4
# 3             4           2              4
# 4             4           3              4

# %% [markdown]
# Milestone Extraction
#
# We expect to filter the prefixes by the milestone, and train the model for each milestone separately to observe if there will be an improvement in the model explainability as well as performance

# %%
if milestone != 'All':
  log_df = log_df[log_df['milestone'] == milestone]
else:
  log_df = log_df[(log_df['prefix_length'] > min_size) & (log_df['prefix_length'] <= max_size) ]

# %% [markdown]
# #### Data Analysis

# %%
#Checking the Balance of the Dataset, by the target variable
print('Distribution of cases by the target variable - next event\n')
print(log_df.groupby(['next_activity'])['prefix_id'].nunique())
# Out:
# Distribution of cases by the target variable - next event
#
# next_activity
# O_ACCEPTED     2231
# O_CANCELLED    3645
# O_CREATED      7007
# O_DECLINED      801
# O_SELECTED     2007
# O_SENT         7007
# O_SENT_BACK    3440
# Name: prefix_id, dtype: int64

# %% [markdown]
# We can see that there is an imbalance in the dataset, by the next activity name, as well as a very high dimensionality in the target variable.
# Therefore, we can reduce the imbalance and high dimensionality of data by grouping some of the activity name.

# %% [markdown]
# Balancing the dataset

# %%
def balance(df):
  # Dictonary with the mapping of columns
  
  # based on the paper : BPIC_2012 Winner, DOI: 10.1007/978-3-642-36285-9_24

  # group_dict = {'A_ACCEPTED':'A_ACCEPTED',    
  #   'A_ACTIVATED' :   'A_APPROVED_ACTIVATED',
  #   'A_APPROVED':  'A_APPROVED_ACTIVATED',
  #   'A_CANCELLED': 'A_CANCELLED_DECLINED' ,
  #   'A_DECLINED': 'A_CANCELLED_DECLINED' ,
  #   'A_PARTLYSUBMITTED': 'REDUNDANT',
  #   'A_PREACCEPTED':'A_PREACCEPTED',
  #   'A_REGISTERED' : 'REDUNDANT',
  #   'O_ACCEPTED' : 'REDUNDANT',
  #   'O_CANCELLED' :  'O_CANCELLED_DECLINED' ,
  #   'O_CREATED':'REDUNDANT',
  #   'O_DECLINED' :'O_CANCELLED_DECLINED' ,
  #   'O_SELECTED' : 'REDUNDANT', 
  #   'O_SENT':'O_SENT',
  #   'O_SENT_BACK' : 'O_SENT_BACK'}


  # df['next_activity'].replace(group_dict, inplace=True)
  # #Dropping the minority classes
  # df = df.drop(df[df.next_activity == 'REDUNDANT'].index)
 

  return df

# %%
log_df = balance(log_df)



#replacing empty cells of categorical columns with 'none'
log_df = log_df.fillna('none')

# %%
# Check the balance

print('Distribution of cases by the target variable - next event\n')
print(log_df.groupby(['next_activity'])['prefix_id'].nunique())
# Out:
# Distribution of cases by the target variable - next event
#
# next_activity
# O_ACCEPTED     2231
# O_CANCELLED    3645
# O_CREATED      7007
# O_DECLINED      801
# O_SELECTED     2007
# O_SENT         7007
# O_SENT_BACK    3440
# Name: prefix_id, dtype: int64

# %%
#minority reduction. if certain samples are < 5, reduce via below

#log_df = log_df.drop(log_df[log_df.next_activity == 'W_Afhandelen leads'].index)

# %% [markdown]
# Reduce Loops
#
# Function : `reduce_loops(df)`, Author: Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
if experiment == 'No_Loops':
  log_df = reduce_loops(log_df)

# %% [markdown]
# #### Data Encoding and Vectorization

# %% [markdown]
# Index creating for data encoding
# Function : `create_index(log_df, column)`, Author: Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
# Index creation for activity

ac_index = create_index(log_df, 'task')
index_ac = {v: k for k, v in ac_index.items()}

# Index creation for unit

rl_index = create_index(log_df, 'role')
index_rl = {v: k for k, v in rl_index.items()}

# Index creation for next activity

ne_index = create_index(log_df, 'next_activity')

index_ne = {v: k for k, v in ne_index.items()}

#mapping the dictionary values as columns in the dataframe
log_df['ac_index'] = log_df['task'].map(ac_index)
log_df['rl_index'] = log_df['role'].map(rl_index)
log_df['ne_index'] = log_df['next_activity'].map(ne_index)

print(rl_index)
print(index_rl)
log_df.head()
# Out:
# {'none': 0, 'role_     10138': 1, 'role_     10228': 2, 'role_     10609': 3, 'role_     10629': 4, 'role_     10779': 5, 'role_     10789': 6, 'role_     10809': 7, 'role_     10859': 8, 'role_     10861': 9, 'role_     10862': 10, 'role_     10863': 11, 'role_     10880': 12, 'role_     10881': 13, 'role_     10889': 14, 'role_     10899': 15, 'role_     10909': 16, 'role_     10910': 17, 'role_     10912': 18, 'role_     10913': 19, 'role_     10914': 20, 'role_     10929': 21, 'role_     10931': 22, 'role_     10932': 23, 'role_     10933': 24, 'role_     10935': 25, 'role_     10939': 26, 'role_     10971': 27, 'role_     10972': 28, 'role_     10982': 29, 'role_     11000': 30, 'role_     11001': 31, 'role_     11002': 32, 'role_     11003': 33, 'role_     11009': 34, 'role_     11019': 35, 'role_     11029': 36, 'role_     11049': 37, 'role_     11111': 38, 'role_     11119': 39, 'role_     11120': 40, 'role_     11121': 41, 'role_     11122': 42, 'role_     11169': 43, 'role_     11179': 44, 'role_     11180': 45, 'role_     11181': 46, 'role_     11189': 47, 'role_     11200': 48, 'role_     11201': 49, 'role_     11202': 50, 'role_     11203': 51, 'role_     11259': 52, 'role_     11289': 53, 'role_     11299': 54, 'role_     11300': 55, 'role_     11302': 56, 'role_     11309': 57, 'role_     11319': 58, 'role_     11339': 59}
# {0: 'none', 1: 'role_     10138', 2: 'role_     10228', 3: 'role_     10609', 4: 'role_     10629', 5: 'role_     10779', 6: 'role_     10789', 7: 'role_     10809', 8: 'role_     10859', 9: 'role_     10861', 10: 'role_     10862', 11: 'role_     10863', 12: 'role_     10880', 13: 'role_     10881', 14: 'role_     10889', 15: 'role_     10899', 16: 'role_     10909', 17: 'role_     10910', 18: 'role_     10912', 19: 'role_     10913', 20: 'role_     10914', 21: 'role_     10929', 22: 'role_     10931', 23: 'role_     10932', 24: 'role_     10933', 25: 'role_     10935', 26: 'role_     10939', 27: 'role_     10971', 28: 'role_     10972', 29: 'role_     10982', 30: 'role_     11000', 31: 'role_     11001', 32: 'role_     11002', 33: 'role_     11003', 34: 'role_     11009', 35: 'role_     11019', 36: 'role_     11029', 37: 'role_     11049', 38: 'role_     11111', 39: 'role_     11119', 40: 'role_     11120', 41: 'role_     11121', 42: 'role_     11122', 43: 'role_     11169', 44: 'role_     11179', 45: 'role_     11180', 46: 'role_     11181', 47: 'role_     11189', 48: 'role_     11200', 49: 'role_     11201', 50: 'role_     11202', 51: 'role_     11203', 52: 'role_     11259', 53: 'role_     11289', 54: 'role_     11299', 55: 'role_     11300', 56: 'role_     11302', 57: 'role_     11309', 58: 'role_     11319', 59: 'role_     11339'}
#   prefix_id  caseid        task             role                end_timestamp  \
# 0  173796_1  173796  O_SELECTED  role_     11001  2011-10-03 19:15:53.5370000
# 1  173835_1  173835  O_SELECTED  role_     11180  2011-10-03 18:35:59.2790000
# 2  173871_4  173871  O_SELECTED  role_     10909  2011-10-05 03:40:46.5260000
# 3  173871_4  173871   O_CREATED  role_     10909  2011-10-05 03:40:47.7410000
# 4  173871_4  173871      O_SENT  role_     10909  2011-10-05 03:40:47.8250000
#
#                    trace_start  timelapsed next_activity    milestone  \
# 0  2011-10-03 19:15:53.5370000           0     O_CREATED   O_SELECTED
# 1  2011-10-03 18:35:59.2790000           0     O_CREATED   O_SELECTED
# 2  2011-10-05 03:40:46.5260000           0    O_DECLINED  O_SENT_BACK
# 3  2011-10-05 03:40:46.5260000           0    O_DECLINED  O_SENT_BACK
# 4  2011-10-05 03:40:46.5260000           0    O_DECLINED  O_SENT_BACK
#
#    milestone_id  task_index  prefix_length  ac_index  rl_index  ne_index
# 0             1           1              1         3        31         2
# 1             1           1              1         3        45         2
# 2             4           1              4         3        16         3
# 3             4           2              4         2        16         3
# 4             4           3              4         4        16         3

# %%
print(ne_index)
# Out:
# {'O_ACCEPTED': 0, 'O_CANCELLED': 1, 'O_CREATED': 2, 'O_DECLINED': 3, 'O_SELECTED': 4, 'O_SENT': 5, 'O_SENT_BACK': 6}

# %% [markdown]
# Splitting the dataframe into test and train sets
#
# Function : `split_train_test(df, percentage)`, Author: Bemali Wickramanayake

# %%
# Split validation datasets
log_df_train, log_df_test = split_train_test(log_df, 0.3) # 70%/30%

# %% [markdown]
# Normalize Numerical Features
#
# Function : `normalize_events(log_df,args,numerical_features)`, Author: Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
numerical_features = ['timelapsed']
log_df_train = normalize_events(log_df_train,args,numerical_features)
log_df_test = normalize_events(log_df_test,args,numerical_features)

# %%
training_traces = len(log_df_train['prefix_id'].unique())
test_traces = len(log_df_test['prefix_id'].unique())


print('Number of traces in training set is:'+str(training_traces))
print('Number of traces in test set is:'+str(test_traces))
# Out:
# Number of traces in training set is:18297
# Number of traces in test set is:7841

# %%
#Checking the Balance of the Dataset, by the target variable
print('training dataset')
print(log_df_train.groupby(['next_activity'])['prefix_id'].nunique())
print("")
print('test dataset')
print(log_df_test.groupby(['next_activity'])['prefix_id'].nunique())
print("")
# Out:
# training dataset
# next_activity
# O_ACCEPTED     1488
# O_CANCELLED    2569
# O_CREATED      4943
# O_DECLINED      551
# O_SELECTED     1458
# O_SENT         4938
# O_SENT_BACK    2350
# Name: prefix_id, dtype: int64
#
# test dataset
# next_activity
# O_ACCEPTED      743
# O_CANCELLED    1076
# O_CREATED      2064
# O_DECLINED      250
# O_SELECTED      549
# O_SENT         2069
# O_SENT_BACK    1090
# Name: prefix_id, dtype: int64

# %% [markdown]
# Reformat events: converting the dataframe into a dictionary to aid vectorization
#
# Function : `reformat_events(log_df, ac_index, rl_index,ne_index)`, Author: Renuka Sindagatta/ Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
log_train = reformat_events(log_df_train, ac_index, rl_index,ne_index)
log_test = reformat_events(log_df_test, ac_index, rl_index,ne_index)
#log_val = reformat_events(log_df_val, ac_index, rl_index,ne_index)

#print a sample of the dictionary
print(log_train[100])
# Out:
# {'caseid': '183052_4', 'ac_order': [5, 4, 2, 3], 'rl_order': [37, 39, 39, 39], 'tbtw': [1.7717983402221018, -0.5480646825080113, -0.5480646825080113, -0.5480646825080113], 'next_activity': 3}

# %% [markdown]
# Vectorization: Convert the data dictionaries into trainable multi dimensional tensors
#
# Function: `vectorization(log,ac_index, rl_index, ne_index,trc_len,cases)` , Author: Bemali Wickramanayake, Inspired by the code of: Renuka Sindagatta

# %%
#Obtain the maximum trc_len and cases for each set

trc_len_train, cases_train = lengths(log_train)
trc_len_test, cases_test = lengths(log_test)
#trc_len_val, cases_val = lengths(log_val)

trc_len = max([trc_len_train, trc_len_test])

print("trace_length: "+str(trc_len)+", training cases: "+str(cases_train)+", test cases: "+str(cases_test) )
# Out:
# trace_length: 29, training cases: 18298, test cases: 7842

# %% [markdown]
# converting the training log (dictionary) into a Tensor

# %%
vec_train = vectorization(log_train,ac_index, rl_index, ne_index,trc_len,cases_train)
vec_test = vectorization(log_test,ac_index, rl_index, ne_index,trc_len,cases_test)
#vec_val = vectorization(log_val,ac_index, rl_index, ne_index,trc_len,cases_val)

# %%
vec_train['prefixes']['x_ac_inp']
# Out:
# array([[1., 3., 4., ..., 0., 0., 0.],
#        [1., 3., 4., ..., 0., 0., 0.],
#        [2., 3., 0., ..., 0., 0., 0.],
#        ...,
#        [4., 2., 1., ..., 0., 0., 0.],
#        [3., 0., 0., ..., 0., 0., 0.],
#        [2., 3., 0., ..., 0., 0., 0.]])

# %% [markdown]
# #### Generating Initial Embedding Weights for shared Model

# %%
ac_weights = to_categorical(sorted(index_ac.keys()), num_classes = len(ac_index))
ac_weights[0] = 0 # embedding weights for label none = 0

rl_weights =  to_categorical(sorted(index_rl.keys()), num_classes = len(rl_index))
rl_weights[0] = 0 # embeddig weights for label none = 0

# %%
# converting the weights 
weights = {'ac_weights':ac_weights, 'rl_weights':rl_weights, 'next_activity':len(ne_index)}

# converting the weights into a dictionary and saving
indexes = {'index_ac':index_ac, 'index_rl':index_rl,'index_ne':index_ne}

# converting the weights into a dictionary and saving
pre_index = {'ac_index':ac_index, 'rl_index':rl_index,'ne_index':ne_index}

# %% [markdown]
# ### Experiments

# %% [markdown]
# #### Load the Required Libraries

# %%
# !pip3 install pyflowchart
# Out:
# Requirement already satisfied: pyflowchart in c:\users\mithr\miniconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: chardet in c:\users\mithr\miniconda3\lib\site-packages (from pyflowchart) (4.0.0)
# Requirement already satisfied: astunparse in c:\users\mithr\miniconda3\lib\site-packages (from pyflowchart) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mithr\miniconda3\lib\site-packages (from astunparse->pyflowchart) (0.36.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\mithr\miniconda3\lib\site-packages (from astunparse->pyflowchart) (1.15.0)

# %%
import os
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import callbacks, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model

import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from pyflowchart import *
import plotly.express as px

from models.shared import *
from models.specialised import *
from models.explain import *

# %% [markdown]
# #### shared Model

# %%
shared = shared_model(vec_train, weights, indexes, pre_index, args)

# %%
shared.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
shared.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ac_input (InputLayer)           [(None, 5)]          0
# __________________________________________________________________________________________________
# rl_input (InputLayer)           [(None, 5)]          0
# __________________________________________________________________________________________________
# ac_embedding (Embedding)        (None, 5, 6)         36          ac_input[0][0]
# __________________________________________________________________________________________________
# rl_embedding (Embedding)        (None, 5, 60)        3600        rl_input[0][0]
# __________________________________________________________________________________________________
# t_input (InputLayer)            [(None, 5, 1)]       0
# __________________________________________________________________________________________________
# full_embs (Concatenate)         (None, 5, 67)        0           ac_embedding[0][0]
#                                                                  rl_embedding[0][0]
#                                                                  t_input[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 5, 67)        0           full_embs[0][0]
# __________________________________________________________________________________________________
# alpha (Bidirectional)           (None, 5, 100)       47200       dropout_3[0][0]
# __________________________________________________________________________________________________
# alpha_dense (TimeDistributed)   (None, 5, 1)         101         alpha[0][0]
# __________________________________________________________________________________________________
# beta (Bidirectional)            (None, 5, 100)       47200       dropout_3[0][0]
# __________________________________________________________________________________________________
# timestep_attention (Softmax)    (None, 5, 1)         0           alpha_dense[0][0]
# __________________________________________________________________________________________________
# feature_attention (TimeDistribu (None, 5, 67)        6767        beta[0][0]
# __________________________________________________________________________________________________
# feature_importance (Multiply)   (None, 5, 67)        0           timestep_attention[0][0]
#                                                                  feature_attention[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 67)           0           feature_importance[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 67)           0           lambda_2[0][0]
# __________________________________________________________________________________________________
# act_output (Dense)              (None, 7)            476         dropout_4[0][0]
# ==================================================================================================
# Total params: 105,380
# Trainable params: 105,380
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
batch_size = 64 # 32, 64, 128, 256
epochs = 200

# %%
shared_history = shared_model_fit(vec_train, shared, indexes, pre_index, MY_WORKSPACE_DIR, batch_size, epochs, args)
# Out:
# Epoch 1/200
# 244/244 [==============================] - 12s 26ms/step - loss: 1.4562 - accuracy: 0.5022 - val_loss: 0.8859 - val_accuracy: 0.8036
# Epoch 2/200
# 244/244 [==============================] - 6s 24ms/step - loss: 0.6834 - accuracy: 0.7682 - val_loss: 0.4723 - val_accuracy: 0.80876898 - accuracy
# Epoch 3/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4983 - accuracy: 0.8029 - val_loss: 0.3972 - val_accuracy: 0.8645
# Epoch 4/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4571 - accuracy: 0.8130 - val_loss: 0.3788 - val_accuracy: 0.8372
# Epoch 5/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.4395 - accuracy: 0.8125 - val_loss: 0.3699 - val_accuracy: 0.8317- loss: 0.4388  - ETA: 0s - loss: 0.4406 - accuracy: 0. - ETA: 0s - loss: 0.4400 - ac
# Epoch 6/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4295 - accuracy: 0.8140 - val_loss: 0.3605 - val_accuracy: 0.8466
# Epoch 7/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4248 - accuracy: 0.8146 - val_loss: 0.3523 - val_accuracy: 0.8641
# Epoch 8/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4192 - accuracy: 0.8141 - val_loss: 0.3570 - val_accuracy: 0.83024196 - accuracy: 0.
# Epoch 9/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4132 - accuracy: 0.8135 - val_loss: 0.3550 - val_accuracy: 0.8310
# Epoch 10/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.4106 - accuracy: 0.8150 - val_loss: 0.3532 - val_accuracy: 0.8375
# Epoch 11/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4077 - accuracy: 0.8137 - val_loss: 0.3485 - val_accuracy: 0.8583
# Epoch 12/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.4043 - accuracy: 0.8160 - val_loss: 0.3516 - val_accuracy: 0.8306
# Epoch 13/200
# 244/244 [==============================] - 6s 23ms/step - loss: 0.4027 - accuracy: 0.8182 - val_loss: 0.3607 - val_accuracy: 0.8128 0.81
# Epoch 14/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.4013 - accuracy: 0.8150 - val_loss: 0.3382 - val_accuracy: 0.8747 - loss: 0.3999 - accu - ETA: 3s - loss: - ETA: 1s - loss: 0.4018 - accura - ETA: 1s - loss: 0
# Epoch 15/200
# 244/244 [==============================] - 6s 24ms/step - loss: 0.4016 - accuracy: 0.8157 - val_loss: 0.3437 - val_accuracy: 0.8543
# Epoch 16/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3996 - accuracy: 0.8152 - val_loss: 0.3472 - val_accuracy: 0.8554
# Epoch 17/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3987 - accuracy: 0.8155 - val_loss: 0.3489 - val_accuracy: 0.8587
# Epoch 18/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3992 - accuracy: 0.8174 - val_loss: 0.3425 - val_accuracy: 0.8667
# Epoch 19/200
# 244/244 [==============================] - 5s 21ms/step - loss: 0.3961 - accuracy: 0.8189 - val_loss: 0.3576 - val_accuracy: 0.8179
# Epoch 20/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3948 - accuracy: 0.8178 - val_loss: 0.3500 - val_accuracy: 0.8288 2s - loss: 0.3940  - ETA: 1s - loss: 0.3937
# Epoch 21/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3965 - accuracy: 0.8151 - val_loss: 0.3440 - val_accuracy: 0.8412- ETA: 0s - loss:
# Epoch 22/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3989 - accuracy: 0.8149 - val_loss: 0.3478 - val_accuracy: 0.8364
# Epoch 23/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3936 - accuracy: 0.8159 - val_loss: 0.3416 - val_accuracy: 0.8630
# Epoch 24/200
# 244/244 [==============================] - 5s 22ms/step - loss: 0.3925 - accuracy: 0.8195 - val_loss: 0.3448 - val_accuracy: 0.8415 0.81

# %%
plot_shared(shared_history)

# %%
trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'shared_model_'+subset+'.h5')
shared.save(trained_model)
# Out:
# C:\Users\mithr\miniconda3\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# ##### Load Saved Model and Evaluate

# %%
shared_trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'shared_model_'+subset+'.h5')
shared_model = load_model(shared_trained_model)

# %%
x_test,y_test = generate_inputs_shared(vec_test,args,indexes)

print("Evaluate on test data")

results = shared_model.evaluate(x_test, y_test, batch_size=batch_size)
y_pred_shared = shared_model.predict(x_test)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 123/123 [==============================] - 2s 8ms/step - loss: 0.4054 - accuracy: 0.8148
# test loss, test acc: [0.40542811155319214, 0.8148431777954102]

# %%
m1_y_test = y_test.argmax(axis=1)
m1_y_pred = y_pred_shared.argmax(axis=1)

# %% [markdown]
# Classification Report

# %%
target_names = [index_ne[i] for i in range(len(index_ne))]

print(classification_report(y_test.argmax(axis=1), y_pred_shared.argmax(axis=1), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#   O_ACCEPTED       0.65      0.96      0.78       743
#  O_CANCELLED       0.52      0.60      0.55      1076
#    O_CREATED       1.00      1.00      1.00      2065
#   O_DECLINED       0.00      0.00      0.00       250
#   O_SELECTED       0.99      0.50      0.66       549
#       O_SENT       1.00      1.00      1.00      2069
#  O_SENT_BACK       0.57      0.57      0.57      1090
#
#     accuracy                           0.81      7842
#    macro avg       0.68      0.66      0.65      7842
# weighted avg       0.81      0.81      0.80      7842
# C:\Users\mithr\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mithr\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mithr\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Confusion Matrix

# %%
matrix = confusion_matrix(y_test.argmax(axis=1), y_pred_shared.argmax(axis=1))
print(matrix)
matrix_sum = np.sum(matrix, axis=1).reshape(-1,1)
matrix_perc = matrix / matrix_sum
df_cm = pd.DataFrame(matrix_perc, index = [index_ne[i] for i in range(len(index_ne))],
                  columns = [index_ne[i] for i in range(len(index_ne))])

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# [[ 711   18    0    0    2    0   12]
#  [  88  645    0    0    2    0  341]
#  [   0    1 2064    0    0    0    0]
#  [ 232    9    0    0    0    0    9]
#  [  45  124    0    0  275    0  105]
#  [   0    0    0    0    0 2069    0]
#  [  12  452    0    0    0    0  626]]
# <AxesSubplot:>

# %% [markdown]
# #### specialised Model

# %%
specialised = specialised_model(vec_train, weights, indexes, pre_index, args)

# %%
specialised.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
specialised.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ac_input (InputLayer)           [(None, 5, 6)]       0
# __________________________________________________________________________________________________
# rl_input (InputLayer)           [(None, 5, 60)]      0
# __________________________________________________________________________________________________
# t_input (InputLayer)            [(None, 5, 1)]       0
# __________________________________________________________________________________________________
# beta_ac (Bidirectional)         (None, 5, 100)       22800       ac_input[0][0]
# __________________________________________________________________________________________________
# beta_rl (Bidirectional)         (None, 5, 100)       44400       rl_input[0][0]
# __________________________________________________________________________________________________
# beta_t (Bidirectional)          (None, 5, 100)       20800       t_input[0][0]
# __________________________________________________________________________________________________
# feature_attention_ac (TimeDistr (None, 5, 6)         606         beta_ac[0][0]
# __________________________________________________________________________________________________
# feature_attention_rl (TimeDistr (None, 5, 60)        6060        beta_rl[0][0]
# __________________________________________________________________________________________________
# feature_attention_t (TimeDistri (None, 5, 1)         101         beta_t[0][0]
# __________________________________________________________________________________________________
# ac_importance (Multiply)        (None, 5, 6)         0           feature_attention_ac[0][0]
#                                                                  ac_input[0][0]
# __________________________________________________________________________________________________
# rl_importance (Multiply)        (None, 5, 60)        0           feature_attention_rl[0][0]
#                                                                  rl_input[0][0]
# __________________________________________________________________________________________________
# t_importance (Multiply)         (None, 5, 1)         0           feature_attention_t[0][0]
#                                                                  t_input[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 5, 67)        0           ac_importance[0][0]
#                                                                  rl_importance[0][0]
#                                                                  t_importance[0][0]
# __________________________________________________________________________________________________
# alpha (Bidirectional)           (None, 5, 100)       47200       concat[0][0]
# __________________________________________________________________________________________________
# alpha_dense (TimeDistributed)   (None, 5, 1)         101         alpha[0][0]
# __________________________________________________________________________________________________
# timestep_attention (Softmax)    (None, 5, 1)         0           alpha_dense[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 5, 67)        0           timestep_attention[0][0]
#                                                                  concat[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 67)           0           multiply_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 67)           0           lambda_3[0][0]
# __________________________________________________________________________________________________
# act_output (Dense)              (None, 7)            476         dropout_5[0][0]
# ==================================================================================================
# Total params: 142,544
# Trainable params: 142,544
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
batch_size = 64 # 32, 64, 128, 256
epochs = 200

# %%
specialised_history = specialised_model_fit(vec_train, specialised, indexes, pre_index, MY_WORKSPACE_DIR, batch_size, epochs, args)
# Out:
# This is the output file path  c:\Users\mithr\Documents\GitHub\KBS-SI-Paper\BPIC12\models\model_specialised_All_{epoch:02d}-{val_loss:.2f}.h5
# Epoch 1/200
# 244/244 [==============================] - 17s 39ms/step - loss: 1.6537 - accuracy: 0.3768 - val_loss: 1.3460 - val_accuracy: 0.5148
# Epoch 2/200
# 244/244 [==============================] - 8s 32ms/step - loss: 1.2706 - accuracy: 0.5499 - val_loss: 1.1150 - val_accuracy: 0.7392
# Epoch 3/200
# 244/244 [==============================] - 8s 32ms/step - loss: 1.0548 - accuracy: 0.7010 - val_loss: 0.8575 - val_accuracy: 0.7800
# Epoch 4/200
# 244/244 [==============================] - 8s 31ms/step - loss: 0.9032 - accuracy: 0.7065 - val_loss: 0.7258 - val_accuracy: 0.7836
# Epoch 5/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.8154 - accuracy: 0.7192 - val_loss: 0.6564 - val_accuracy: 0.77490.8225 - accu - ETA: 2s - loss: - ETA: 1s - loss: 0.8174 - accura - ETA: 1s - loss: 0.8 - ETA: 0s - loss: 0.8176
# Epoch 6/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.7687 - accuracy: 0.7223 - val_loss: 0.6192 - val_accuracy: 0.7763
# Epoch 7/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.7300 - accuracy: 0.7237 - val_loss: 0.5840 - val_accuracy: 0.7785
# Epoch 8/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.7041 - accuracy: 0.7240 - val_loss: 0.5564 - val_accuracy: 0.7792 - accuracy: 0.72 - ETA: 0s - loss: 0.7017 - accuracy: 0. - ETA: 0s - loss: 0.701
# Epoch 9/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.6818 - accuracy: 0.7290 - val_loss: 0.5359 - val_accuracy: 0.7814
# Epoch 10/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.6622 - accuracy: 0.7305 - val_loss: 0.5187 - val_accuracy: 0.7818
# Epoch 11/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.6470 - accuracy: 0.7318 - val_loss: 0.5043 - val_accuracy: 0.7832- ETA: 1s - loss: 0.646 - ETA: 0s - loss: 0.6470
# Epoch 12/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.6351 - accuracy: 0.7389 - val_loss: 0.4931 - val_accuracy: 0.7843
# Epoch 13/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.6292 - accuracy: 0.7379 - val_loss: 0.4835 - val_accuracy: 0.7898
# Epoch 14/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.6140 - accuracy: 0.7437 - val_loss: 0.4741 - val_accuracy: 0.7938
# Epoch 15/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.6057 - accuracy: 0.7456 - val_loss: 0.4672 - val_accuracy: 0.7964
# Epoch 16/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.6015 - accuracy: 0.7508 - val_loss: 0.4554 - val_accuracy: 0.8080
# Epoch 17/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5865 - accuracy: 0.7555 - val_loss: 0.4468 - val_accuracy: 0.8128
# Epoch 18/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5823 - accuracy: 0.7554 - val_loss: 0.4408 - val_accuracy: 0.8153
# Epoch 19/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5748 - accuracy: 0.7608 - val_loss: 0.4355 - val_accuracy: 0.8146
# Epoch 20/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5647 - accuracy: 0.7630 - val_loss: 0.4294 - val_accuracy: 0.8193
# Epoch 21/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5596 - accuracy: 0.7632 - val_loss: 0.4258 - val_accuracy: 0.8164 1s - loss: 0 -
# Epoch 22/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5518 - accuracy: 0.7690 - val_loss: 0.4209 - val_accuracy: 0.8240
# Epoch 23/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5499 - accuracy: 0.7670 - val_loss: 0.4174 - val_accuracy: 0.8186 4s - loss: 0.5633 - accura - ETA: 4s - loss: 0.5596 - accura - ETA - ETA: 2s - ETA: 1s - loss: 0.5530 - accu - ETA
# Epoch 24/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5454 - accuracy: 0.7687 - val_loss: 0.4107 - val_accuracy: 0.8302
# Epoch 25/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5456 - accuracy: 0.7687 - val_loss: 0.4088 - val_accuracy: 0.8328
# Epoch 26/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5332 - accuracy: 0.7743 - val_loss: 0.4081 - val_accuracy: 0.8262
# Epoch 27/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5266 - accuracy: 0.7795 - val_loss: 0.4058 - val_accuracy: 0.8291
# Epoch 28/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5246 - accuracy: 0.7779 - val_loss: 0.4008 - val_accuracy: 0.8310 - accuracy - ETA: 2s - los - ETA: 0s - loss:
# Epoch 29/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5183 - accuracy: 0.7817 - val_loss: 0.4004 - val_accuracy: 0.8270
# Epoch 30/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5150 - accuracy: 0.7859 - val_loss: 0.3969 - val_accuracy: 0.8310
# Epoch 31/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5104 - accuracy: 0.7905 - val_loss: 0.3949 - val_accuracy: 0.8353
# Epoch 32/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5044 - accuracy: 0.7899 - val_loss: 0.3909 - val_accuracy: 0.8332
# Epoch 33/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.5069 - accuracy: 0.7856 - val_loss: 0.3925 - val_accuracy: 0.8313
# Epoch 34/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.5011 - accuracy: 0.7905 - val_loss: 0.3896 - val_accuracy: 0.8346
# Epoch 35/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4956 - accuracy: 0.7904 - val_loss: 0.3859 - val_accuracy: 0.8357
# Epoch 36/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4887 - accuracy: 0.7956 - val_loss: 0.3854 - val_accuracy: 0.8350uracy:
# Epoch 37/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4839 - accuracy: 0.7961 - val_loss: 0.3749 - val_accuracy: 0.8434
# Epoch 38/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4814 - accuracy: 0.7943 - val_loss: 0.3727 - val_accuracy: 0.8441
# Epoch 39/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4750 - accuracy: 0.7965 - val_loss: 0.3722 - val_accuracy: 0.8357
# Epoch 40/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4700 - accuracy: 0.7945 - val_loss: 0.3666 - val_accuracy: 0.8455
# Epoch 41/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4681 - accuracy: 0.7975 - val_loss: 0.3634 - val_accuracy: 0.8466 - ac
# Epoch 42/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4657 - accuracy: 0.7956 - val_loss: 0.3642 - val_accuracy: 0.8466: 0.4660 - accuracy
# Epoch 43/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4611 - accuracy: 0.7986 - val_loss: 0.3640 - val_accuracy: 0.8452
# Epoch 44/200
# 244/244 [==============================] - 8s 35ms/step - loss: 0.4599 - accuracy: 0.7957 - val_loss: 0.3600 - val_accuracy: 0.8466
# Epoch 45/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4560 - accuracy: 0.7986 - val_loss: 0.3571 - val_accuracy: 0.8572- loss: 0.4564 - accuracy
# Epoch 46/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4574 - accuracy: 0.7966 - val_loss: 0.3567 - val_accuracy: 0.8550
# Epoch 47/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4523 - accuracy: 0.7974 - val_loss: 0.3585 - val_accuracy: 0.8441
# Epoch 48/200
# 244/244 [==============================] - 8s 35ms/step - loss: 0.4531 - accuracy: 0.7980 - val_loss: 0.3582 - val_accuracy: 0.8408ETA: 3s - loss: 0.447 - ETA: 1s
# Epoch 49/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4478 - accuracy: 0.8009 - val_loss: 0.3544 - val_accuracy: 0.8444 0s - loss: 0.4506 - accuracy: 0.80 - ETA: 0s - loss: 0.4508 - accuracy:  - ETA: 0s - loss: 0.450
# Epoch 50/200
# 244/244 [==============================] - 8s 35ms/step - loss: 0.4472 - accuracy: 0.8005 - val_loss: 0.3557 - val_accuracy: 0.8441 accu
# Epoch 51/200
# 244/244 [==============================] - 9s 38ms/step - loss: 0.4442 - accuracy: 0.8013 - val_loss: 0.3550 - val_accuracy: 0.8444
# Epoch 52/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4415 - accuracy: 0.8042 - val_loss: 0.3563 - val_accuracy: 0.8444 1s - loss: 0.4371  - ETA
# Epoch 53/200
# 244/244 [==============================] - 8s 35ms/step - loss: 0.4403 - accuracy: 0.8050 - val_loss: 0.3549 - val_accuracy: 0.8532
# Epoch 54/200
# 244/244 [==============================] - 8s 35ms/step - loss: 0.4382 - accuracy: 0.8070 - val_loss: 0.3537 - val_accuracy: 0.8546
# Epoch 55/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4356 - accuracy: 0.8020 - val_loss: 0.3528 - val_accuracy: 0.8539
# Epoch 56/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4312 - accuracy: 0.8070 - val_loss: 0.3558 - val_accuracy: 0.8517
# Epoch 57/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4389 - accuracy: 0.8007 - val_loss: 0.3517 - val_accuracy: 0.8543
# Epoch 58/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4336 - accuracy: 0.8048 - val_loss: 0.3539 - val_accuracy: 0.8539ETA: 1s - l - ETA: 0s - loss: 0.4346 - accuracy:
# Epoch 59/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4286 - accuracy: 0.8044 - val_loss: 0.3515 - val_accuracy: 0.8572
# Epoch 60/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4300 - accuracy: 0.8047 - val_loss: 0.3533 - val_accuracy: 0.8525
# Epoch 61/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4321 - accuracy: 0.8032 - val_loss: 0.3552 - val_accuracy: 0.8517ETA: 0s - loss: 0.4335 -
# Epoch 62/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4274 - accuracy: 0.8053 - val_loss: 0.3504 - val_accuracy: 0.8568A: 4s - loss: 0.4352 - accuracy - ETA: 4s - loss: 0.4374 - accuracy:  - ETA: 3s - loss: 0.4356 - accuracy: 0.80 - E - ETA: 2s - loss: 0.4347 - accuracy:  - ETA: 2s - loss: 0.4328 - accu - ETA: 1s - loss: 0.4318 - accu - ETA: 1s - loss: - ETA: 0s - loss: 0.4
# Epoch 63/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4264 - accuracy: 0.8045 - val_loss: 0.3533 - val_accuracy: 0.85464279 -  - ETA: 2s - loss: 0
# Epoch 64/200
# 244/244 [==============================] - 9s 36ms/step - loss: 0.4284 - accuracy: 0.8066 - val_loss: 0.3514 - val_accuracy: 0.8576
# Epoch 65/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4248 - accuracy: 0.8081 - val_loss: 0.3523 - val_accuracy: 0.8565
# Epoch 66/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4251 - accuracy: 0.8082 - val_loss: 0.3532 - val_accuracy: 0.8557
# Epoch 67/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4262 - accuracy: 0.8036 - val_loss: 0.3512 - val_accuracy: 0.8572
# Epoch 68/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4211 - accuracy: 0.8036 - val_loss: 0.3519 - val_accuracy: 0.8587
# Epoch 69/200
# 244/244 [==============================] - 9s 35ms/step - loss: 0.4188 - accuracy: 0.8137 - val_loss: 0.3490 - val_accuracy: 0.8594
# Epoch 70/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4253 - accuracy: 0.8064 - val_loss: 0.3487 - val_accuracy: 0.8572
# Epoch 71/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4214 - accuracy: 0.8083 - val_loss: 0.3500 - val_accuracy: 0.8554
# Epoch 72/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4192 - accuracy: 0.8126 - val_loss: 0.3503 - val_accuracy: 0.8572
# Epoch 73/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4174 - accuracy: 0.8090 - val_loss: 0.3486 - val_accuracy: 0.8597
# Epoch 74/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4164 - accuracy: 0.8128 - val_loss: 0.3487 - val_accuracy: 0.8601
# Epoch 75/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4167 - accuracy: 0.8122 - val_loss: 0.3505 - val_accuracy: 0.8565
# Epoch 76/200
# 244/244 [==============================] - 8s 34ms/step - loss: 0.4139 - accuracy: 0.8128 - val_loss: 0.3488 - val_accuracy: 0.8590
# Epoch 77/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4148 - accuracy: 0.8114 - val_loss: 0.3502 - val_accuracy: 0.8576
# Epoch 78/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4122 - accuracy: 0.8133 - val_loss: 0.3487 - val_accuracy: 0.8587
# Epoch 79/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4105 - accuracy: 0.8150 - val_loss: 0.3507 - val_accuracy: 0.85830 - ETA: 0s - loss: 0.4120 - accura
# Epoch 80/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4109 - accuracy: 0.8126 - val_loss: 0.3518 - val_accuracy: 0.8565
# Epoch 81/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4159 - accuracy: 0.8100 - val_loss: 0.3470 - val_accuracy: 0.8594
# Epoch 82/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4115 - accuracy: 0.8144 - val_loss: 0.3475 - val_accuracy: 0.8587
# Epoch 83/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4077 - accuracy: 0.8144 - val_loss: 0.3505 - val_accuracy: 0.8546
# Epoch 84/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4088 - accuracy: 0.8162 - val_loss: 0.3503 - val_accuracy: 0.8594
# Epoch 85/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4073 - accuracy: 0.8149 - val_loss: 0.3495 - val_accuracy: 0.8579s - loss: 0.4070 -
# Epoch 86/200
# 244/244 [==============================] - 8s 32ms/step - loss: 0.4098 - accuracy: 0.8146 - val_loss: 0.3507 - val_accuracy: 0.8576
# Epoch 87/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4076 - accuracy: 0.8151 - val_loss: 0.3515 - val_accuracy: 0.8565
# Epoch 88/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4052 - accuracy: 0.8139 - val_loss: 0.3517 - val_accuracy: 0.8583
# Epoch 89/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4105 - accuracy: 0.8135 - val_loss: 0.3522 - val_accuracy: 0.8557
# Epoch 90/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4055 - accuracy: 0.8150 - val_loss: 0.3508 - val_accuracy: 0.8576
# Epoch 91/200
# 244/244 [==============================] - 8s 33ms/step - loss: 0.4060 - accuracy: 0.8155 - val_loss: 0.3508 - val_accuracy: 0.8561

# %%
plot_specialised(specialised_history)

# %%
trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'specialised_model_'+subset+'.h5')
specialised.save(trained_model)
# Out:
# C:\Users\mithr\miniconda3\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# ##### Load Saved Model and Evaluate

# %%
trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'specialised_model_'+subset+'.h5')
specialised_model = load_model(trained_model)

# %% [markdown]
# Evaluating Prediction Performance

# %%
# Generating Inputs

x_test,y_test = generate_inputs(vec_test,args,indexes,experiment)

# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")

results = specialised_model.evaluate(x_test, y_test, batch_size=batch_size)
y_pred = specialised_model.predict(x_test)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 123/123 [==============================] - 6s 13ms/step - loss: 0.4212 - accuracy: 0.8133
# test loss, test acc: [0.4212116599082947, 0.8133129477500916]

# %%
target_names = [index_ne[i] for i in range(len(index_ne))]

print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#   O_ACCEPTED       0.65      0.95      0.77       743
#  O_CANCELLED       0.54      0.47      0.50      1076
#    O_CREATED       1.00      1.00      1.00      2065
#   O_DECLINED       0.00      0.00      0.00       250
#   O_SELECTED       0.95      0.51      0.66       549
#       O_SENT       1.00      1.00      1.00      2069
#  O_SENT_BACK       0.54      0.70      0.61      1090
#
#     accuracy                           0.81      7842
#    macro avg       0.67      0.66      0.65      7842
# weighted avg       0.80      0.81      0.80      7842

# %% [markdown]
# Confusion Matrix

# %%
matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print(matrix)
matrix_sum = np.sum(matrix, axis=1).reshape(-1,1)
matrix_perc = matrix / matrix_sum
df_cm = pd.DataFrame(matrix_perc, index = [index_ne[i] for i in range(len(index_ne))],
                  columns = [index_ne[i] for i in range(len(index_ne))])

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# [[ 703   24    0    1    7    1    7]
#  [  87  501    0    1    2    1  484]
#  [   0    0 2065    0    0    0    0]
#  [ 228    5    0    0    5    0   12]
#  [  45   85    0    0  279    1  139]
#  [   1    0    0    0    0 2068    0]
#  [  13  314    0    0    0    1  762]]
# <AxesSubplot:>

# %%
m2_y_test = y_test.argmax(axis=1)
m2_y_pred = y_pred.argmax(axis=1)
st = pd.DataFrame({"y_test": m2_y_test, "m1_y_pred" : m1_y_pred, "m2_y_pred":m2_y_pred})
st.to_csv("st_O.csv")

import scipy.stats as stats
stats.ttest_ind(st['m1_y_pred'], st['m2_y_pred'])
# Out:
# Ttest_indResult(statistic=-6.070495318497191, pvalue=1.304539068297345e-09)
